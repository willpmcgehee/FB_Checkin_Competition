# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
group1X = []
group1Y = []
group2X = []
group2Y = []
group3X = []
group3Y = []
for i in range(0,2000):
    group1X.append(np.random.normal(0,1))
    group1Y.append(np.random.normal(0,1))

    group2X.append(np.random.logistic(0,1))
    group2Y.append(np.random.logistic(0,1))

    group3X.append(np.random.normal(5,2))
    group3Y.append(np.random.normal(5,2))

# %%
color1 =(np.random.uniform(0,1),np.random.uniform(0,1),np.random.uniform(0,1))
color2 =(np.random.uniform(0,1),np.random.uniform(0,1),np.random.uniform(0,1))
plt.scatter(group1X,group1Y,c=color1,alpha=.5)
plt.scatter(group3X,group3Y,c=color2,alpha=.5)
plt.show()
